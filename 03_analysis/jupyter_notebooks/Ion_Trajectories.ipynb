# %%
import numpy as _np
import matplotlib.pyplot as _plt

import os
import sys
parent_folder = os.path.abspath('../../../luxe-backgrounds/06_analysis/')
if parent_folder not in sys.path:
    sys.path.append(parent_folder)
import beamDump

# %%
file = "../../../bdsim-develop/pwfa/WButcher/output.root"

# %%
TD = beamDump.TrajData(file)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 TD = beamDump.TrajData(file)
#
# File ~/PhD/PhD-git/luxe-backgrounds/06_analysis/beamDump.py:382, in TrajData.__init__(self, inputfilename)
#     380 def __init__(self, inputfilename):
#     381     self.inputfilename = inputfilename
# --> 382     self.bdsim_data = _bd.Data.Load(inputfilename)
#     383     self.Event = self.bdsim_data.GetEvent()
#     384     self.EventTree = self.bdsim_data.GetEventTree()
#
# File ~/PhD/PhD-git/pybdsim/src/pybdsim/Data.py:88, in Load(filepath, messageio)
#      86 if "*" not in filepath:
#      87     if not _os.path.exists(filepath):
# ---> 88         raise IOError("File: {} does not exist.".format(filepath))
#      89     extension = filepath.split('.')[-1]
#      90 else:
#
# OSError: File: ../../../bdsim-develop/pwfa/WButcher/output.root does not exist.

# %%
for i in range(100):
    T = TD.Trajectory(i)
    if len(T.track_table) > 1:
        print(i)
# Out:
# 0
# 1
# 7
# 14
# 15
# 23
# 28
# 48
# 61
# 72
# 79
# 81
# 82
# 83
# 85
# 89

# %%
T = TD.Trajectory(1)
T.printTrajLog()
# Out:
# index  partID     min Z     max Z     trackID   parentID  parentIDX parentStepIDX  primaryStepIDX
# 0      11         1.148     1.148     2         1         1         25             25
# 1      11         -0.0      1.148     1         0         1         0              -1

# %%
T.getPostProcessIDs(1)
# Out:
# [(-1.0, -1.0),
#  (2.0, 10.0),
#  (2.0, 10.0),
#  (2.0, 10.0),
#  (2.0, 10.0),
#  (2.0, 10.0),
#  (2.0, 10.0),
#  (2.0, 10.0),
#  (2.0, 10.0),
#  (2.0, 10.0),
#  (2.0, 10.0),
#  (2.0, 2.0),
#  (2.0, 2.0)]

# %%
TD.findUnknownPartID(includeNucleus=True)
# Out:
# Looking for unknown particle. Event 100/100: |██████████████████████████████████████████████████| 100.0% Complete
# set()

# %%
beamDump.G4Dict.Particle_type_dict
# Out:
# {0: {'Name': 'All', 'Symbol': 'All'},
#  11: {'Name': 'electron', 'Symbol': '$e^-$'},
#  -11: {'Name': 'positron', 'Symbol': '$e^+$'},
#  12: {'Name': 'electron_neutrino', 'Symbol': '${\\nu}_e$'},
#  -12: {'Name': 'electron_anti_neutrino', 'Symbol': '$\\overline{{\\nu}_e}$'},
#  13: {'Name': 'muon', 'Symbol': '${\\mu}^-$'},
#  -13: {'Name': 'anti_muon', 'Symbol': '${\\mu}^+$'},
#  14: {'Name': 'muon_neutrino', 'Symbol': '${\\nu}_{\\mu}$'},
#  -14: {'Name': 'muon_anti_neutrino', 'Symbol': '$\\overline{{\\nu}_{\\mu}}$'},
#  22: {'Name': 'photon', 'Symbol': '$\\gamma$'},
#  111: {'Name': 'pion_zero', 'Symbol': '${\\pi}^0$'},
#  211: {'Name': 'pion_plus', 'Symbol': '${\\pi}^+$'},
#  -211: {'Name': 'pion_minus', 'Symbol': '${\\pi}^-$'},
#  221: {'Name': 'eta_meson', 'Symbol': '$\\eta$'},
#  130: {'Name': 'kaon_zero_L', 'Symbol': '$K^0_L$'},
#  310: {'Name': 'kaon_zero_S', 'Symbol': '$K^0_S$'},
#  311: {'Name': 'kaon_zero', 'Symbol': '$K^0$'},
#  321: {'Name': 'kaon_plus', 'Symbol': '$K^+$'},
#  -321: {'Name': 'kaon_minus', 'Symbol': '$K^-$'},
#  2112: {'Name': 'neutron', 'Symbol': 'n'},
#  2212: {'Name': 'proton', 'Symbol': 'p'},
#  3122: {'Name': 'lambda', 'Symbol': '$\\Lambda$'},
#  1000010020: {'Name': 'deuterium', 'Symbol': 'D'}}

# %%
PD = TD.bdsim_data.GetParticleData()
